# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.166666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere are several solutions, from simplest to most robust:\n\n## Solution 1: Simple String Split (Basic)\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    return s3_uri.split('/')[2]\n\n# Test\nprint(get_bucket_name('s3://my-bucket-name/path/to/file.txt'))\n# Output: my-bucket-name\n```\n\n## Solution 2: Using `urllib` (More Robust)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test\nprint(get_bucket_name('s3://my-bucket-name/path/to/file.txt'))\n# Output: my-bucket-name\n```\n\n## Solution 3: Regex (Most Flexible)\n```python\nimport re\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    match = re.match(r's3://([a-z0-9\\-\\.]+)', s3_uri)\n    return match.group(1) if match else None\n\n# Test\nprint(get_bucket_name('s3://my-bucket-name/path/to/file.txt'))\n# Output: my-bucket-name\n```\n\n## Solution 4: Using `boto3` (AWS SDK)\n```python\nimport boto3\nfrom botocore.compat import urlsplit\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    parts = urlsplit(s3_uri, scheme='s3')\n    return parts.netloc\n\n# Test\nprint(get_bucket_name('s3://my-bucket-name/path/to/file.txt'))\n# Output: my-bucket-name\n```\n\n## Comparison\n\n| Method | Pros | Cons |\n|--------|------|------|\n| String Split | Simple, fast | Assumes correct format |\n| `urllib.parse` | Standard library, robust | Requires import |\n| Regex | Validates format, flexible | Regex overhead |\n| `boto3` | AWS-native | Extra dependency |\n\n**Recommendation:** Use **Solution 2** (`urllib.parse`) for most cases - it's standard library, robust, and handles edge cases well.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., 's3://my-bucket-name/path/to/file.txt') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good pedagogical structure by progressing from simple to robust implementations with a clear recommendation. However, it has meaningful gaps: Solution 1 shouldn't be presented as viable without caveats about its brittleness, none of the solutions include proper error handling or input validation, and important AWS S3 URI formats are completely missing. The recommendation of Solution 2 is sound, but the overall package would benefit from defensive coding practices and more comprehensive coverage of real-world S3 URI patterns."
#   },
#   {
#     "output": "# CloudFormation Template: S3 Bucket with Versioning and Public Access Blocked\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for a basic S3 bucket with versioning enabled and public access blocked\",\n  \"Resources\": {\n    \"S3Bucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": {\n          \"Fn::Sub\": \"my-bucket-${AWS::AccountId}-${AWS::Region}\"\n        },\n        \"VersioningConfiguration\": {\n          \"Status\": \"Enabled\"\n        }\n      }\n    },\n    \"S3BucketPublicAccessBlockConfiguration\": {\n      \"Type\": \"AWS::S3::BucketPublicAccessBlock\",\n      \"Properties\": {\n        \"BucketName\": {\n          \"Ref\": \"S3Bucket\"\n        },\n        \"BlockPublicAcls\": true,\n        \"BlockPublicPolicy\": true,\n        \"IgnorePublicAcls\": true,\n        \"RestrictPublicBuckets\": true\n      }\n    }\n  },\n  \"Outputs\": {\n    \"BucketName\": {\n      \"Description\": \"Name of the S3 bucket\",\n      \"Value\": {\n        \"Ref\": \"S3Bucket\"\n      }\n    },\n    \"BucketArn\": {\n      \"Description\": \"ARN of the S3 bucket\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\"S3Bucket\", \"Arn\"]\n      }\n    }\n  }\n}\n```\n\n## Key Features:\n\n1. **S3 Bucket Resource**: Creates a basic S3 bucket with a dynamically generated unique name\n2. **Versioning Enabled**: `VersioningConfiguration` with `Status: \"Enabled\"` allows version history of objects\n3. **Public Access Blocked**: `AWS::S3::BucketPublicAccessBlock` resource blocks all four types of public access:\n   - `BlockPublicAcls`: true\n   - `BlockPublicPolicy`: true\n   - `IgnorePublicAcls`: true\n   - `RestrictPublicBuckets`: true\n\n4. **Outputs**: Provides the bucket name and ARN for reference after deployment\n\n## Usage:\nSave this as a `.json` file and deploy via AWS CloudFormation console or CLI:\n```bash\naws cloudformation create-stack --stack-name my-s3-stack --template-body file://template.json\n```",
#     "test_case": {
#       "task": "Create a CloudFormation template JSON object that defines a basic S3 bucket with versioning enabled and public access blocked",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution successfully delivers the core requirements with correct syntax and proper AWS resource configuration. The template is production-ready for basic use cases and demonstrates good CloudFormation practices. However, it lacks some security enhancements and architectural flexibility that would be expected in a more robust template. The omissions are reasonable tradeoffs for a 'basic' template as specified, but represent common improvements in real-world scenarios."
#   },
#   {
#     "output": "# AWS Lambda API Gateway Event Parser\n\nHere's a Python function that extracts the HTTP method and request path from an API Gateway proxy integration event:\n\n```python\ndef extract_http_details(event):\n    \"\"\"\n    Extract HTTP method and request path from an API Gateway proxy integration event.\n    \n    Args:\n        event (dict): The AWS Lambda event object from API Gateway\n        \n    Returns:\n        dict: A dictionary containing 'method' and 'path' keys\n        \n    Raises:\n        ValueError: If the event is not a valid API Gateway proxy integration event\n    \"\"\"\n    try:\n        # Extract HTTP method and path from the event\n        http_method = event.get('httpMethod')\n        request_path = event.get('path')\n        \n        # Validate that required fields exist\n        if http_method is None or request_path is None:\n            raise ValueError(\n                \"Invalid API Gateway proxy integration event. \"\n                \"Missing 'httpMethod' or 'path' field.\"\n            )\n        \n        return {\n            'method': http_method,\n            'path': request_path\n        }\n    \n    except AttributeError:\n        raise ValueError(\"Event object is not a valid dictionary\")\n\n\n# Alternative version with additional details\ndef extract_http_details_extended(event):\n    \"\"\"\n    Extract comprehensive HTTP details from an API Gateway proxy integration event.\n    \n    Args:\n        event (dict): The AWS Lambda event object from API Gateway\n        \n    Returns:\n        dict: A dictionary containing method, path, and additional HTTP details\n    \"\"\"\n    try:\n        return {\n            'method': event.get('httpMethod', 'UNKNOWN'),\n            'path': event.get('path', 'UNKNOWN'),\n            'query_string_parameters': event.get('queryStringParameters'),\n            'headers': event.get('headers', {}),\n            'body': event.get('body'),\n            'request_context': event.get('requestContext', {})\n        }\n    \n    except AttributeError as e:\n        raise ValueError(f\"Invalid event object: {str(e)}\")\n```\n\n## Usage Examples\n\n```python\n# Example 1: Basic usage\nevent = {\n    'httpMethod': 'GET',\n    'path': '/users/123',\n    'headers': {'Content-Type': 'application/json'},\n    'body': None\n}\n\nresult = extract_http_details(event)\nprint(result)\n# Output: {'method': 'GET', 'path': '/users/123'}\n\n\n# Example 2: POST request with body\nevent = {\n    'httpMethod': 'POST',\n    'path': '/users',\n    'headers': {'Content-Type': 'application/json'},\n    'body': '{\"name\": \"John\", \"email\": \"john@example.com\"}',\n    'queryStringParameters': None\n}\n\nresult = extract_http_details(event)\nprint(result)\n# Output: {'method': 'POST', 'path': '/users'}\n\n\n# Example 3: Using extended version\nresult = extract_http_details_extended(event)\nprint(result)\n# Output includes method, path, query parameters, headers, body, and request context\n\n\n# Example 4: Error handling\ntry:\n    invalid_event = {}\n    extract_http_details(invalid_event)\nexcept ValueError as e:\n    print(f\"Error: {e}\")\n    # Output: Error: Invalid API Gateway proxy integration event. Missing 'httpMethod' or 'path' field.\n```\n\n## Complete Lambda Handler Example\n\n```python\nimport json\n\ndef lambda_handler(event, context):\n    \"\"\"\n    Example Lambda handler that uses the HTTP extraction function.\n    \"\"\"\n    try:\n        http_details = extract_http_details(event)\n        \n        return {\n            'statusCode': 200,\n            'body': json.dumps({\n                'message': 'Success',\n                'method': http_details['method'],\n                'path': http_details['path']\n            })\n        }\n    \n    except ValueError as e:\n        return {\n            'statusCode': 400,\n            'body': json.dumps({'error': str(e)})\n        }\n```\n\n## Key Features\n\n\u2705 **Extracts",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS Lambda event object and extracts the HTTP method and request path from an API Gateway proxy integration event",
#       "format": "python"
#     },
#     "score": 7.5,
#     "reasoning": "The solution successfully addresses the core requirement with a clean, focused implementation that safely extracts HTTP method and path. The error handling is appropriate for the base function. However, the extended variant introduces inconsistency by silently defaulting to 'UNKNOWN' instead of matching the base function's validation approach. The AttributeError handling is defensive but unnecessary given the dict.get() usage. Overall, this is a solid, production-ready solution with good documentation, but could be improved with more consistent design patterns and edge case consideration."
#   }
# ]
