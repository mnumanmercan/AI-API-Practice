# %%
# Load environment variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
system = """
    Your answer should be concise and to the point.
    Avoid unnecessary details and explanations.
    """
add_user_message(messages, "Generate a one sentence movie idea")

# High temperature - more creative
answer = chat(messages, temperature=1.0)
answer
# Out:
# "Here's a movie idea:\n\n**When a burned-out sleep scientist accidentally discovers that everyone on Earth is sharing the same dream, she has 72 hours to navigate the collective unconscious and stop an ancient entity from trapping humanity in permanent sleep before she loses her own grip on reality.**"
